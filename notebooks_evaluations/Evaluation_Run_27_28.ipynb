# %%
# %pylab inline
import os
import sys
sys.path.insert(0, os.getenv("HOME") + '/src/syntist')
from utils import ImagePlotter
from flyem_syn_eval import eval as flyem_eval

IP = ImagePlotter()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [raw]
# RUN 27, CX, iteration = 100000 & 200000
# key aspects: with reweighting; higher learning rate(le=1e-6); smaller, more detailed network (fmap=24, *2)
# Training settings:
#     SOLVER:
#         learning rate = 1e-6
#     NETWORK:
#         features maps to start: 24
#         factor = 2
#         depth: 3
#     DATA:
#         trained on cx1_1
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %% [raw]
# RUN 28, CX, iteration = 100000 & 200000
# key aspects: with reweighting; higher learning rate(le=1e-6); smaller, more detailed network (fmap=24, *1)
# Training settings:
#     SOLVER:
#         learning rate = 1e-6
#     NETWORK:
#         features maps to start: 24
#         factor = 1
#         depth: 3
#     DATA:
#         trained on cx1_1
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %% [raw]
# RUN 25, CX, iteration = 100'000
# key aspects: with reweighting, higher learning rate(lr=1e-6), larger network(fmap=24/3),
# Training settings:
#     SOLVER:
#         learning rate = 1e-6
#     NETWORK:
#         features maps to start: 24
#         factor = 3
#         depth: 3
#     DATA:
#         trained on cx1_1
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %% [raw]
# Questions looked at in this notebook:
# 1.) Difference between 100'000 and 200'000 iterations of training (previously only run for 100'000 iterations)
# 2.) Difference for architectures: compare results for 24_1 (run28), 24_2 (run27), 24_3 (run25)
# 3.a & b) check overfitting for run 27/28

# %% [markdown]
# 1.) DIFFERENCE BETWEEN 100'000 and 200'000 ITERATIONS OF TRAINING (Results on Validation dataset)

# %%
fig, ax = plt.subplots()
ax.plot(cx1_2_27_100000_results_turagalab.rr, cx1_2_27_100000_results_turagalab.pp, 'r.-', label='27_100000')
ax.plot(cx1_2_27_200000_results_turagalab.rr, cx1_2_27_200000_results_turagalab.pp, 'r', label='27_200000')
ax.plot(cx1_2_28_100000_results_turagalab.rr, cx1_2_28_100000_results_turagalab.pp, 'b.-', label='28_100000')
ax.plot(cx1_2_28_200000_results_turagalab.rr, cx1_2_28_200000_results_turagalab.pp, 'b', label='28_200000')
ax.plot(cx1_2_results_flyem.rr, cx1_2_results_flyem.pp, 'k.-', label='cx1_2_flyem')
legend = ax.legend(loc='lower left', bbox_to_anchor=(1, 0))
plt.xlabel('recall')
plt.ylabel('precision')
plt.grid()
plt.show()

# %% [markdown]
# 2.) DIFFERENCE IN ARCHITECTURES: compare results for 24_1 (run27), 24_2 (run28), 24_3 (run25)
# (Results on Validation dataset)

# %%
fig, ax = plt.subplots()
ax.plot(cx1_2_25_100000_results_turagalab.rr, cx1_2_25_100000_results_turagalab.pp, 'g.-', label='24_3 100000 (run 25)')
ax.plot(cx1_2_27_100000_results_turagalab.rr, cx1_2_27_100000_results_turagalab.pp, 'r.-', label='24_2 100000 (run 27)')
# ax.plot(cx1_2_27_200000_results_turagalab.rr, cx1_2_27_200000_results_turagalab.pp, 'r', label='24_2 200000 (run 27)')
ax.plot(cx1_2_28_100000_results_turagalab.rr, cx1_2_28_100000_results_turagalab.pp, 'b.-', label='24_1 100000 (run 28)')
#ax.plot(cx1_2_28_200000_results_turagalab.rr, cx1_2_28_200000_results_turagalab.pp, 'b', label='24_1 200000 (run 28)')
ax.plot(cx1_2_results_flyem.rr, cx1_2_results_flyem.pp, 'k.-', label='cx1_2_flyem')
legend = ax.legend(loc='lower left', bbox_to_anchor=(1, 0))
plt.xlabel('recall')
plt.ylabel('precision')
plt.grid()
plt.show()

# %% [markdown]
# 3.a) CHECK OVERFITTING RUN 27

# %%
fig, ax = plt.subplots()
ax.plot(cx1_1_27_100000_results_turagalab.rr, cx1_1_27_100000_results_turagalab.pp, 'r.-', label='27_train_100000')
ax.plot(cx1_1_27_200000_results_turagalab.rr, cx1_1_27_200000_results_turagalab.pp, 'b.-',   label='27_train_200000')
ax.plot(cx1_2_27_100000_results_turagalab.rr, cx1_2_27_100000_results_turagalab.pp, 'r', label='27_val_100000')
ax.plot(cx1_2_27_200000_results_turagalab.rr, cx1_2_27_200000_results_turagalab.pp, 'b', label='27_val_200000')
ax.plot(cx1_2_results_flyem.rr, cx1_2_results_flyem.pp, 'k.-', label='cx1_2_flyem')
legend = ax.legend(loc='lower left', bbox_to_anchor=(1, 0))
plt.xlabel('recall')
plt.ylabel('precision')
plt.grid()
plt.show()

# %% [markdown]
# 3.b) CHECK OVERFITTING RUN 28

# %%
fig, ax = plt.subplots()
ax.plot(cx1_1_28_100000_results_turagalab.rr, cx1_1_28_100000_results_turagalab.pp, 'r.-', label='28_train_100000')
ax.plot(cx1_1_28_200000_results_turagalab.rr, cx1_1_28_200000_results_turagalab.pp, 'b.-',   label='28_train_200000')
ax.plot(cx1_2_28_100000_results_turagalab.rr, cx1_2_28_100000_results_turagalab.pp, 'r', label='28_val_100000')
ax.plot(cx1_2_28_200000_results_turagalab.rr, cx1_2_28_200000_results_turagalab.pp, 'b',   label='28_val_200000')
ax.plot(cx1_2_results_flyem.rr, cx1_2_results_flyem.pp, 'k.-', label='cx1_2_flyem')
legend = ax.legend(loc='lower left', bbox_to_anchor=(1, 0))
plt.xlabel('recall')
plt.ylabel('precision')
plt.grid()
plt.show()

# %%
# IMPORTS:

# %%
# run 27, 200000
inputfilename = os.getenv("HOME") + '/projects/syntist/processing/20170630/165802/200000/CX_val_inference200000_part0_full.hdf'
IP.visualize_pred_presyn_locations(inputfilename, shape=[500, 800], num_slices=6)
# Out:
# ('Raw: ', (769, 2794, 2464))
# ('GT BM Presyn: ', (769, 2794, 2464))
# ('Pred BM Presyn: ', (769, 2794, 2464))

# %%
# run 27

# %%
# 100'000 iterations, train (cx1_1)
cx1_1_27_100000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170630', '165802',
                             '100000','cx1_1_syn_locations_sigma2_minpeakdist10.json')
cx1_1_27_100000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_1_27_100000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('1'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
# 100'000 iterations, val (cx1_2)
cx1_2_27_100000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170630', '165802',
                             '100000','cx1_2_syn_locations_sigma2_minpeakdist10.json')
cx1_2_27_100000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_2_27_100000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('2'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
# 200'000 iterations, train (cx1_1)
cx1_1_27_200000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170630', '165802',
                             '200000','cx1_1_syn_locations_sigma2_minpeakdist10.json')
cx1_1_27_200000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_1_27_200000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('1'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
# 200'000 iterations, val (cx1_2)
cx1_2_27_200000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170630', '165802',
                             '200000','cx1_2_syn_locations_sigma2_minpeakdist10.json')
cx1_2_27_200000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_2_27_200000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('2'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
# run 28

# %%
# 100'000 iterations, train (cx1_1)
cx1_1_28_100000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170630', '165844',
                             '100000','cx1_1_syn_locations_sigma2_minpeakdist10.json')
cx1_1_28_100000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_1_28_100000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('1'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
# 100'000 iterations, val (cx1_2)
cx1_2_28_100000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170630', '165844',
                             '100000','cx1_2_syn_locations_sigma2_minpeakdist10.json')
cx1_2_28_100000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_2_28_100000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('2'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
# 200'000 iterations, train (cx1_1)
cx1_1_28_200000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170630', '165844',
                             '200000','cx1_1_syn_locations_sigma2_minpeakdist10.json')
cx1_1_28_200000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_1_28_200000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('1'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
# 200'000 iterations, val (cx1_2)
cx1_2_28_200000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170630', '165844',
                             '200000','cx1_2_syn_locations_sigma2_minpeakdist10.json')
cx1_2_28_200000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_2_28_200000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('2'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
# run 25

# %%
cx1_1_25_100000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170625', '085613', '100000','cx1_1_syn_locations_sigma2_minpeakdist10.json')
cx1_1_25_100000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_1_25_100000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('1'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
cx1_2_25_100000_json_filename = os.path.join(os.getenv("HOME")+'/projects/syntist/processing', '20170625', '085613', '100000','cx1_2_syn_locations_sigma2_minpeakdist10.json')
cx1_2_25_100000_results_turagalab = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info(cx1_2_25_100000_json_filename),
                                                 flyem_eval.cx_synapse_groundtruth('2'),
                                                 conf_thresholds=np.arange(0.0,0.98,0.02))

# %%
cx1_2_results_flyem = flyem_eval.evaluate_pr(flyem_eval.Tbar_Info('fpl_unet_pred_cx1_2_baseline', 'emdata2:8000','cb7dc','roi_cx1_2'),
                                             flyem_eval.cx_synapse_groundtruth('2'),
                                             conf_thresholds=np.arange(0.7,0.98,0.02))
