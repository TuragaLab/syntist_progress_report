# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# %pylab inline
import os, h5py, sys
sys.path.insert(0, os.getenv("HOME") + '/src/syntist')
from utils import ImagePlotter
from flyem_syn_eval import eval as flyem_eval
from scipy.spatial import KDTree

import matplotlib.pylab as plt
import matplotlib.gridspec as gridspec
from scipy import ndimage

IP = ImagePlotter()
# Out:
# <style>.container { width:80% !important; }</style>
# Populating the interactive namespace from numpy and matplotlib

# %%
# EXAMPLES HIGH CONFIDENCE AND FP (WRONG)
bb_shape_zyx     = [6, 132, 132]

# %%
prob = sorted_probs_FP_turagalab[-1]
bb_center_xyz    = FP_turagalab[prob]
print('Prob: ', prob, 'Location: ', [bb_center_xyz[2], bb_center_xyz[1], bb_center_xyz[0]])
bb_raw, bb_gt_presyn, bb_pred_presyn = IP.get_bbs_from_hdf5(hdf5_path, hdf5_datasets, bb_center_xyz, bb_shape_zyx, dataset_offset_zyx, dataset_shape_zyx)
IP.visualize_bb(bb_raw, bb_gt_presyn, bb_pred_presyn)
# Out:
# ('Prob: ', 0.9013608524497787, 'Location: ', [10212, 3278, 9210])
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)

# %%
prob = sorted_probs_FP_turagalab[-2]
bb_center_xyz    = FP_turagalab[prob]
print('Prob: ', prob, 'Location: ', [bb_center_xyz[2], bb_center_xyz[1], bb_center_xyz[0]])
bb_raw, bb_gt_presyn, bb_pred_presyn = IP.get_bbs_from_hdf5(hdf5_path, hdf5_datasets, bb_center_xyz, bb_shape_zyx, dataset_offset_zyx, dataset_shape_zyx)
IP.visualize_bb(bb_raw, bb_gt_presyn, bb_pred_presyn)
# Out:
# ('Prob: ', 0.8956791408154372, 'Location: ', [9944, 2891, 9592])
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)

# %%
prob = sorted_probs_FP_turagalab[-3]
bb_center_xyz    = FP_turagalab[prob]
print('Prob: ', prob, 'Location: ', [bb_center_xyz[2], bb_center_xyz[1], bb_center_xyz[0]])
bb_raw, bb_gt_presyn, bb_pred_presyn = IP.get_bbs_from_hdf5(hdf5_path, hdf5_datasets, bb_center_xyz, bb_shape_zyx, dataset_offset_zyx, dataset_shape_zyx)
IP.visualize_bb(bb_raw, bb_gt_presyn, bb_pred_presyn)
# Out:
# ('Prob: ', 0.88761772651538451, 'Location: ', [10245, 3162, 8875])
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)

# %%
prob = sorted_probs_FP_turagalab[-4]
bb_center_xyz    = FP_turagalab[prob]
print('Prob: ', prob, 'Location: ', [bb_center_xyz[2], bb_center_xyz[1], bb_center_xyz[0]])
bb_raw, bb_gt_presyn, bb_pred_presyn = IP.get_bbs_from_hdf5(hdf5_path, hdf5_datasets, bb_center_xyz, bb_shape_zyx, dataset_offset_zyx, dataset_shape_zyx)
IP.visualize_bb(bb_raw, bb_gt_presyn, bb_pred_presyn)
# Out:
# ('Prob: ', 0.88484306546179337, 'Location: ', [10107, 2952, 9854])
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)

# %%
prob = sorted_probs_FP_turagalab[-5]
bb_center_xyz    = FP_turagalab[prob]
print('Prob: ', prob, 'Location: ', [bb_center_xyz[2], bb_center_xyz[1], bb_center_xyz[0]])
bb_raw, bb_gt_presyn, bb_pred_presyn = IP.get_bbs_from_hdf5(hdf5_path, hdf5_datasets, bb_center_xyz, bb_shape_zyx, dataset_offset_zyx, dataset_shape_zyx)
IP.visualize_bb(bb_raw, bb_gt_presyn, bb_pred_presyn)
# Out:
# ('Prob: ', 0.88471132191320079, 'Location: ', [10269, 3258, 8617])
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)

# %%
prob = sorted_probs_FP_turagalab[-6]
bb_center_xyz    = FP_turagalab[prob]
print('Prob: ', prob, 'Location: ', [bb_center_xyz[2], bb_center_xyz[1], bb_center_xyz[0]])
bb_raw, bb_gt_presyn, bb_pred_presyn = IP.get_bbs_from_hdf5(hdf5_path, hdf5_datasets, bb_center_xyz, bb_shape_zyx, dataset_offset_zyx, dataset_shape_zyx)
IP.visualize_bb(bb_raw, bb_gt_presyn, bb_pred_presyn)
# Out:
# ('Prob: ', 0.87366944339134534, 'Location: ', [10005, 2584, 9206])
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)

# %%
prob = sorted_probs_FP_turagalab[-7]
bb_center_xyz    = FP_turagalab[prob]
print('Prob: ', prob, 'Location: ', [bb_center_xyz[2], bb_center_xyz[1], bb_center_xyz[0]])
bb_raw, bb_gt_presyn, bb_pred_presyn = IP.get_bbs_from_hdf5(hdf5_path, hdf5_datasets, bb_center_xyz, bb_shape_zyx, dataset_offset_zyx, dataset_shape_zyx)
IP.visualize_bb(bb_raw, bb_gt_presyn, bb_pred_presyn)
# Out:
# ('Prob: ', 0.84586588486619263, 'Location: ', [10212, 4035, 8080])
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)

# %%
prob = sorted_probs_FP_turagalab[-8]
bb_center_xyz    = FP_turagalab[prob]
print('Prob: ', prob, 'Location: ', [bb_center_xyz[2], bb_center_xyz[1], bb_center_xyz[0]])
bb_raw, bb_gt_presyn, bb_pred_presyn = IP.get_bbs_from_hdf5(hdf5_path, hdf5_datasets, bb_center_xyz, bb_shape_zyx, dataset_offset_zyx, dataset_shape_zyx)
IP.visualize_bb(bb_raw, bb_gt_presyn, bb_pred_presyn)
# Out:
# ('Prob: ', 0.83730384970980842, 'Location: ', [9877, 2592, 9738])
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)

# %%
prob = sorted_probs_FP_turagalab[-10]
bb_center_xyz    = FP_turagalab[prob]
print('Prob: ', prob, 'Location: ', [bb_center_xyz[2], bb_center_xyz[1], bb_center_xyz[0]])
bb_raw, bb_gt_presyn, bb_pred_presyn = IP.get_bbs_from_hdf5(hdf5_path, hdf5_datasets, bb_center_xyz, bb_shape_zyx, dataset_offset_zyx, dataset_shape_zyx)
IP.visualize_bb(bb_raw, bb_gt_presyn, bb_pred_presyn)
# Out:
# ('Prob: ', 0.82856218070152587, 'Location: ', [9925, 3082, 8755])
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
# (6, 132, 132)
