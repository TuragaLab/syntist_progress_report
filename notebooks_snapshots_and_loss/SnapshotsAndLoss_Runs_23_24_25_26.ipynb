# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# %pylab inline
import os
import sys
sys.path.insert(0, '/groups/turaga/home/krauser/src/syntist')
from utils import LossPlotter
from utils import ImagePlotter
LP = LossPlotter(holt_winters_span=1000, holt_winters_beta=0.2)
IP = ImagePlotter()
# Out:
# <style>.container { width:80% !important; }</style>
# Populating the interactive namespace from numpy and matplotlib

# %%
# VISUALIZE PREDICTION OF PRESYNAPTIC T-BARS

# %% [raw]
# RUN 23, CX, iteration = 100'000
# key aspects: with reweighting, higher learning rate(lr=1e-6), smaller network(fmap=12),
# Training settings:
#     SOLVER:
#         learning rate = 1e-6
#     NETWORK:
#         features maps to start: 12
#         depth: 3
#     DATA:
#         trained on cx1_1
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %%
base_dir_exp = os.path.join(os.getenv("HOME") + '/projects/syntist/experiments/', '20170625', '085445')

# %%
path_to_lossfile = os.path.join(base_dir_exp, '20170625_085445_stderr.err')
LP.plot_loss(path_to_lossfile, min_iteration=0, max_iteration=100000, smoothing='holt_winter')

# %%
path_to_snapshots = os.path.join(base_dir_exp, 'snapshots', 'batch_00099531.hdf')
IP.visualize_pred_presyn_locations(path_to_snapshots)
# Out:
# ('Nonzero slices: ', array([23, 24, 25, 26, 27, 28]))

# %% [raw]
# RUN 24, CX, iteration = 100'000
# key aspects: with reweighting, smaller learning rate(lr=1e-8), smaller network(fmap=12),
# Training settings:
#     SOLVER:
#         learning rate = 1e-8
#     NETWORK:
#         features maps to start: 12
#         depth: 3
#     DATA:
#         trained on cx1_1
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %%
base_dir_exp = os.path.join(os.getenv("HOME") + '/projects/syntist/experiments/', '20170625', '085538')

# %%
path_to_lossfile = os.path.join(base_dir_exp, '20170625_085538_stderr.err')
LP.plot_loss(path_to_lossfile, min_iteration=0, max_iteration=100000, smoothing='holt_winter')

# %%
path_to_snapshots = os.path.join(base_dir_exp, 'snapshots', 'batch_00098977.hdf')
IP.visualize_pred_presyn_locations(path_to_snapshots)
# Out:
# ('Nonzero slices: ', array([10, 11, 12, 13, 14, 15]))

# %% [raw]
# RUN 25, CX, iteration = 100'000
# key aspects: with reweighting, higher learning rate(lr=1e-6), larger network(fmap=24),
# Training settings:
#     SOLVER:
#         learning rate = 1e-6
#     NETWORK:
#         features maps to start: 24
#         depth: 3
#     DATA:
#         trained on cx1_1
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %%
base_dir_exp = os.path.join(os.getenv("HOME") + '/projects/syntist/experiments/', '20170625', '085613')

# %%
path_to_lossfile = os.path.join(base_dir_exp, '20170625_085613_stderr.err')
LP.plot_loss(path_to_lossfile, min_iteration=0, max_iteration=100000, smoothing='holt_winter')

# %%
path_to_snapshots = os.path.join(base_dir_exp, 'snapshots', 'batch_00099520.hdf')
IP.visualize_pred_presyn_locations(path_to_snapshots)
# Out:
# ('Nonzero slices: ', array([28, 29, 30, 31, 32, 33]))

# %% [raw]
# RUN 26, CX, iteration = 100'000
# key aspects: with reweighting, smaller learning rate(lr=1e-8), larger network(fmap=24),
# Training settings:
#     SOLVER:
#         learning rate = 1e-8
#     NETWORK:
#         features maps to start: 24
#         depth: 3
#     DATA:
#         trained on cx1_1
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %%
base_dir_exp = os.path.join(os.getenv("HOME") + '/projects/syntist/experiments/', '20170625', '085633')

# %%
path_to_lossfile = os.path.join(base_dir_exp, '20170625_085633_stderr.err')
LP.plot_loss(path_to_lossfile, min_iteration=0, max_iteration=100000, smoothing='holt_winter')

# %%
path_to_snapshots = os.path.join(base_dir_exp, 'snapshots', 'batch_00099491.hdf')
IP.visualize_pred_presyn_locations(path_to_snapshots)
# Out:
# ('Nonzero slices: ', array([ 7,  8,  9, 10, 11, 12]))
