# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# %pylab inline
import os
import sys
sys.path.insert(0, '/groups/turaga/home/krauser/src/syntist')
from utils import LossPlotter
from utils import ImagePlotter
LP = LossPlotter(holt_winters_span=1000, holt_winters_beta=0.2)
IP = ImagePlotter()
# Out:
# <style>.container { width:80% !important; }</style>
# Populating the interactive namespace from numpy and matplotlib

# %% [raw]
# # VISUALIZE PREDICTION OF PRESYNAPTIC T-BARS
# The goal of run 29, 31, 32 was to check if we can achieve overfitting on a small test volume (cx1_2_small)

# %% [raw]
# RUN 29, CX, iteration = 820'000
# key aspects: check if overfitting possible, with reweighting; higher learning rate(le=1e-6); smaller, more detailed network as before (fmap=24/1)
# Training settings:
#     SOLVER:
#         learning rate = 1e-6
#     NETWORK:
#         features maps to start: 24
#         factor = 1
#         depth: 3
#     DATA:
#         trained on cx1_2_small
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %%
base_dir_exp = os.path.join(os.getenv("HOME") + '/projects/syntist/experiments/', '20170702', '203404')

# %%
path_to_lossfile = os.path.join(base_dir_exp, '20170702_203404_stderr.err')
LP.plot_loss(path_to_lossfile, min_iteration=0, max_iteration=820000, smoothing='holt_winter')

# %%
path_to_snapshots = os.path.join(base_dir_exp, 'snapshots', 'batch_10156433.hdf')
IP.visualize_pred_presyn_locations(path_to_snapshots)
# Out:
# ('Raw: ', (132, 132, 132))
# ('GT BM Presyn: ', (44, 44, 44))
# ('Pred BM Presyn: ', (44, 44, 44))

# %% [raw]
# RUN 31, CX, iteration = 380'000
# key aspects: check if overfitting possible, with reweighting; higher learning rate(le=1e-6); less smaller, more detailed network as before (fmap=24/2)
# Training settings:
#     SOLVER:
#         learning rate = 1e-6
#     NETWORK:
#         features maps to start: 24
#         factor = 2
#         depth: 3
#     DATA:
#         trained on cx1_2_small
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %%
base_dir_exp = os.path.join(os.getenv("HOME") + '/projects/syntist/experiments/', '20170704', '131815')

# %%
path_to_lossfile = os.path.join(base_dir_exp, '20170704_131815_stderr.err')
LP.plot_loss(path_to_lossfile, min_iteration=0, max_iteration=380000, smoothing='holt_winter')

# %%
path_to_snapshots = os.path.join(base_dir_exp, 'snapshots', 'batch_09068313.hdf')
IP.visualize_pred_presyn_locations(path_to_snapshots)
# Out:
# ('Raw: ', (132, 132, 132))
# ('GT BM Presyn: ', (44, 44, 44))
# ('Pred BM Presyn: ', (44, 44, 44))

# %% [markdown]
# RUN 32, CX, iteration = 380'000
# key aspects: check if overfitting possible, with reweighting; higher learning rate(le=1e-6); same network as before (fmap=24/3)
# Training settings:
#     SOLVER:
#         learning rate = 1e-6
#     NETWORK:
#         features maps to start: 24
#         factor = 3
#         depth: 3
#     DATA:
#         trained on cx1_2_small
#     LOSS:
#         euclid
#     REMARKS:
#         - ExclusiveZone around landmarks
#         - reweighting

# %%
base_dir_exp = os.path.join(os.getenv("HOME") + '/projects/syntist/experiments/', '20170707', '215138')

# %%
path_to_lossfile = os.path.join(base_dir_exp, '20170707_215138_stderr.err')
LP.plot_loss(path_to_lossfile, min_iteration=0, max_iteration=60000, smoothing='holt_winter')

# %%
path_to_snapshots = os.path.join(base_dir_exp, 'snapshots', 'batch_01070256.hdf')
IP.visualize_pred_presyn_locations(path_to_snapshots)
# Out:
# ('Raw: ', (132, 132, 132))
# ('GT BM Presyn: ', (44, 44, 44))
# ('Pred BM Presyn: ', (44, 44, 44))
